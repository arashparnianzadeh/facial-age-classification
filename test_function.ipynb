# %% [markdown]
# # Computer Vision Coursework Submission (IN3060)
#
# **Student name, ID and cohort:** Arash Parnianzadeh - 230011641 - UG

# %% [markdown]
# # Notebook Setup
# This notebook loads the saved best model and runs `AgeDetection(path)` without retraining.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import sys

# Relative path after MyDrive.
# Example value: 'CW_Folder' or 'SomeParentFolder/CW_Folder'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'CW_Folder'

GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
sys.path.append(os.path.join(GOOGLE_DRIVE_PATH, 'Code'))
# Out:
# ['CW_Dataset', 'Models', 'Code', 'Personal_Dataset', 'test_function.ipynb']

# %%
import torch
import matplotlib.pyplot as plt

from age_detection import AgeDetection

# %% [markdown]
# ## Test AgeDetection
# The function below loads 4 random images from the personal dataset and shows the predictions from the saved CNN model.

# %%
path_to_test = os.path.join(GOOGLE_DRIVE_PATH, 'Personal_Dataset')
AgeDetection(path_to_test)
# Out:
# [{'image_path': 'drive/My Drive/CW_Folder/Personal_Dataset/old_03.jpg',
#   'predicted_label_index': 3,
#   'predicted_label_name': 'Senior'},
#  {'image_path': 'drive/My Drive/CW_Folder/Personal_Dataset/middle_aged_adults_02.jpg',
#   'predicted_label_index': 1,
#   'predicted_label_name': 'Young'},
#  {'image_path': 'drive/My Drive/CW_Folder/Personal_Dataset/children_01.jpg',
#   'predicted_label_index': 0,
#   'predicted_label_name': 'Child'},
#  {'image_path': 'drive/My Drive/CW_Folder/Personal_Dataset/young_adult_01.jpg',
#   'predicted_label_index': 0,
#   'predicted_label_name': 'Child'}]
